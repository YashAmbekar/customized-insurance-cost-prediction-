# %%
# importing libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# importing the csv file using pandas library 

df = pd.read_csv("C:/Users/HP/Desktop/insurance project/insurance.csv")

# %%
# viewing the data 
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# reading the first five rows

df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# viewing the last five rows 

df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
# number of record and columns 
df.shape
# Out:
# (1338, 7)

# %%
# list of columns 
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
# check the data type of each column 
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
#data information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# check for the duplicates 
df.duplicated().any()
# Out:
# True

# %%
# since the above o/p is True there is/are duplicate values 
# lets view those value/values 

df[df.duplicated()]
# Out:
#      age   sex   bmi  children smoker     region  expenses
# 581   19  male  30.6         0     no  northwest   1639.56

# %%
# droping duplicated values and creating a new data frame 

insurance_data = df.drop_duplicates()

# %%
# check wether the duplicated values are dropped 

insurance_data.shape
# Out:
# (1337, 7)

# %%
# checking for the missing values i.e null values 

insurance_data.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# expenses    False
# dtype: bool

# %%
# to check for the null values in numbers
# this shows the number of missung values in each column and as there are no missing values the count is 0
insurance_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# list of Categorical and numerical columns 
Numerical_columns = insurance_data.select_dtypes(include="number").columns.to_list()
Categorical_columns = insurance_data.select_dtypes(exclude="number").columns.to_list()
print(f"Numerical columns in the data :  {Numerical_columns}")
print(f"Categorical_columns in the data : {Categorical_columns}")
# Out:
# Numerical columns in the data :  ['age', 'bmi', 'children', 'expenses']
# Categorical_columns in the data : ['sex', 'smoker', 'region']

# %%
# statstical measure of numeric data 
insurance_data.describe()
# Out:
#                age          bmi     children      expenses
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.665520     1.095737  13279.121638
# std      14.044333     6.100664     1.205571  12110.359657
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4746.340000
# 50%      39.000000    30.400000     1.000000   9386.160000
# 75%      51.000000    34.700000     2.000000  16657.720000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
# stastical measure of catagorical data 
insurance_data.describe(exclude="number")
# Out:
#          sex smoker     region
# count   1337   1337       1337
# unique     2      2          4
# top     male     no  southeast
# freq     675   1063        364

# %%
# another way of exploring this data is by using value count
insurance_data["sex"].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
insurance_data["smoker"].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
insurance_data["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# Data visualization

# %%
insurance_data["age"].plot(kind="hist")
plt.title("age distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
insurance_data["bmi"].plot(kind="hist")
plt.title("BMI Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
insurance_data["children"].plot(kind="hist")
plt.title("Children distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
insurance_data["expenses"].plot(kind="hist")
plt.title("expence distribution")
plt.show()

# %% [markdown]
# Bar Graph for Categorcal Columns

# %%
insurance_data["children"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='children'>

# %%
insurance_data["sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
insurance_data["region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# Box plot - Numneric columns

# %%
insurance_data["expenses"].plot(kind="box")
plt.title("expenses distribution")
plt.show()

# %%
insurance_data["bmi"].plot(kind="box")
plt.title("bmi distribution")
plt.show()

# %%
insurance_data["age"].plot(kind="box")
plt.title("age distribution")
plt.show()

# %% [markdown]
# pie chart -region

# %%
region_count = insurance_data["region"].value_counts()
region_count
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
plt.pie(labels = region_count.index,
        x = region_count.values,
        shadow=True,
        autopct="%.2f%%",
        explode=(0,0.1,0,0))
plt.title("Distribution of Region")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Correlation Matrix

# %%
corr_data = insurance_data[["age", "bmi", "expenses"]].corr()

plt.figure(figsize=(8,6)) #the figure size
sns.heatmap(round(corr_data, 2), annot = True, cmap= "Blues" , cbar=False)
plt.title("correlation heatmap : age, bmi, expenses")
plt.show()

# %% [markdown]
# Scatter plot :

# %%
plt.scatter(data = insurance_data, x = "age", y = "expenses")

# %%
plt.scatter(data = insurance_data, x = "bmi", y = "expenses")

# %%
plt.scatter(data = insurance_data, x = "bmi", y = "age")

# %% [markdown]
# Insurance Cost for Smoker and Non Smoker:

# %%
smoker_df = insurance_data.groupby("smoker")["expenses"].mean().reset_index()

# %%
smoker_df
# Out:
#   smoker      expenses
# 0     no   8440.660461
# 1    yes  32050.231971

# %%
smoker_df.plot(kind= "bar", x = "smoker", y = "expenses")
# Out:
# <Axes: xlabel='smoker'>

# %% [markdown]
# Insurance cost for Male and Female

# %%
gender_df = insurance_data.groupby("sex")["expenses"].mean().reset_index()
gender_df
# Out:
#       sex      expenses
# 0  female  12569.578897
# 1    male  13974.999111

# %%
gender_df.plot(kind="bar", x = "sex", y = "expenses")
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# Region Wise insurance cost

# %%
region_df = insurance_data.groupby("region")["expenses"].mean().reset_index()
region_df
# Out:
#       region      expenses
# 0  northeast  13406.384691
# 1  northwest  12450.840648
# 2  southeast  14735.411538
# 3  southwest  12346.937908

# %%
region_df.plot(kind="bar", x = "region", y = "expenses")
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# Region Wise BMI:

# %%
bmi_df = insurance_data.groupby("region")["bmi"].mean().reset_index()
bmi_df
# Out:
#       region        bmi
# 0  northeast  29.176235
# 1  northwest  29.197531
# 2  southeast  33.359341
# 3  southwest  30.596615

# %%
bmi_df.plot(kind = "bar", x = "region", y = "bmi")
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# Machine Learning model Development

# %%
insurance_data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
insurance_data["sex"] = le.fit_transform(insurance_data["sex"])
insurance_data["smoker"] = le.fit_transform(insurance_data["smoker"])
insurance_data["region"] = le.fit_transform(insurance_data["region"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13908\3766149893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_data["sex"] = le.fit_transform(insurance_data["sex"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_13908\3766149893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_data["smoker"] = le.fit_transform(insurance_data["smoker"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_13908\3766149893.py:3: SettingWithCopyWarning:
# ...

# %%
insurance_data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       2   1725.55
# 2   28    1  33.0         3       0       2   4449.46
# 3   33    1  22.7         0       0       1  21984.47
# 4   32    1  28.9         0       0       1   3866.86

# %% [markdown]
# Splitting Data into dependent and independent variable
# x = independent variable
# y = dependent variable

# %%
x = insurance_data.drop(columns=["expenses"], axis=1)
y = insurance_data["expenses"]

# %%
x
# Out:
#       age  sex   bmi  children  smoker  region
# 0      19    0  27.9         0       1       3
# 1      18    1  33.8         1       0       2
# 2      28    1  33.0         3       0       2
# 3      33    1  22.7         0       0       1
# 4      32    1  28.9         0       0       1
# ...   ...  ...   ...       ...     ...     ...
# 1333   50    1  31.0         3       0       1
# 1334   18    0  31.9         0       0       0
# 1335   18    0  36.9         0       0       2
# 1336   21    0  25.8         0       0       3
# 1337   61    0  29.1         0       1       1
#
# [1337 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1337, dtype: float64

# %% [markdown]
# Splitting the data into training and texting data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2 ,random_state= 42, shuffle=True)

## checking the shape of splitting data 
print(f"the shape of x trian : {x_train.shape}")
print(f"the shape of y train : {y_train.shape}")

print("-"*30)

print(f"the shape of x test : {X_test.shape}")
print(f"the shape of y test : {y_test.shape}")
# Out:
# the shape of x trian : (1069, 6)
# the shape of y train : (1069,)
# ------------------------------
# the shape of x test : (268, 6)
# the shape of y test : (268,)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
x["age"] = std_scaler.fit_transform(np.array(x["age"]).reshape(-1,1))
x["bmi"] = std_scaler.fit_transform(np.array(x["bmi"]).reshape(-1,1))
x["children"] = std_scaler.fit_transform(np.array(x["children"]).reshape(-1,1))

# %%
x # now the data is converted to a somilar scale
# Out:
#            age  sex       bmi  children  smoker  region
# 0    -1.440418    0 -0.453484 -0.909234       1       3
# 1    -1.511647    1  0.513986 -0.079442       0       2
# 2    -0.799350    1  0.382803  1.580143       0       2
# 3    -0.443201    1 -1.306169 -0.909234       0       1
# 4    -0.514431    1 -0.289506 -0.909234       0       1
# ...        ...  ...       ...       ...     ...     ...
# 1333  0.767704    1  0.054847  1.580143       0       1
# 1334 -1.511647    0  0.202427 -0.909234       0       0
# 1335 -1.511647    0  1.022317 -0.909234       0       2
# 1336 -1.297958    0 -0.797838 -0.909234       0       3
# 1337  1.551231    0 -0.256711 -0.909234       1       1
#
# [1337 rows x 6 columns]

# %% [markdown]
# Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg_model = LinearRegression()

# %%
linear_reg_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Cross Validation

# %%
from sklearn.model_selection import cross_val_score, cross_validate

# %%
result = cross_validate(linear_reg_model, x, y, cv = 5, return_train_score=True, scoring= "r2")
result
# Out:
# {'fit_time': array([0.00597572, 0.00294399, 0.01562238, 0.        , 0.01561952]),
#  'score_time': array([0.0039885, 0.       , 0.       , 0.       , 0.       ]),
#  'test_score': array([0.76123166, 0.70842369, 0.77721808, 0.73369419, 0.75515804]),
#  'train_score': array([0.74739478, 0.7593145 , 0.74328051, 0.75469339, 0.74916825])}

# %%
train_acc = result["train_score"].mean()*100
print("Training Accuracy = ", round(train_acc, 2), "%")
# Out:
# Training Accuracy =  75.08 %

# %%
test_acc = result["test_score"].mean() * 100
print("Testing Accuracy = ", round(test_acc, 2), "%")
# Out:
# Testing Accuracy =  74.71 %

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
models = []
models.append(("LinearRegression", LinearRegression()))
models.append(("Knn", KNeighborsRegressor()))
models.append(("Decision Tree", DecisionTreeRegressor()))
models.append(("Random Forest", RandomForestRegressor()))
for model in models:
    result = cross_validate(model[1], x, y, cv = 5, return_train_score=True, scoring="r2")
    print(model[0])
    train_acc = round((result["train_score"].mean())*100, 2)
    test_acc = round((result["test_score"].mean())*100, 2)
    print(f"Train R2 score : {train_acc}")
    print(f"Test R2 score : {test_acc}")
    print("\n")
# Out:
# LinearRegression
# Train R2 score : 75.08
# Test R2 score : 74.71
#
#
# Knn
# Train R2 score : 81.44
# Test R2 score : 68.89
#
#
# Decision Tree
# Train R2 score : 99.9
# Test R2 score : 71.59
#
#
# Random Forest
# Train R2 score : 97.65
# Test R2 score : 83.43

# %% [markdown]
# Random Forest Hyperparameter Tuning Using RandomSearch

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
parameters = {
    "n_estimators": [100,200,300],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "bootstrap": [True, False]
}

# tunning using random search 
random_search = RandomizedSearchCV(
    param_distributions=parameters, # specify the parameter distribution to sample from
    estimator=RandomForestRegressor(), # Specify the estimatore to use
    cv=5, # number of cross validation folds
    return_train_score=True, # Incude train score in the results
    scoring="r2", # Scoring metric to optimize
    n_jobs = -1 # Use all available CPU cores for computation 
)

# %%
random_search.fit(x, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 5, 10],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    return_train_score=True, scoring='r2')

# %%
random_search.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_depth': 5,
#  'bootstrap': True}

# %%
random_search.cv_results_["mean_train_score"].mean()*100
# Out:
# 91.33837358434211

# %%
random_search.cv_results_["mean_test_score"].mean()*100
# Out:
# 83.09784722592951

# %%
## as you can see above we have reduced the difference hence it is a good model

# %%
RF = RandomForestRegressor(n_estimators=100,
                           min_samples_split=5,
                           min_samples_leaf=2,
                           max_depth=5,
                           bootstrap=True)

# %%
RF.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=5)

# %%
from sklearn.metrics import r2_score

# %%
predicted_train_data = RF.predict(x_train)
train_score = r2_score(y_true=y_train, y_pred=predicted_train_data)
predicted_test_data = RF.predict(X_test)
test_score = r2_score(y_true=y_test, y_pred=predicted_test_data)
print(f"R-squared for training data using random forest: {round(train_score,2)*100}%")
print(f"R-squared for testing data using random forest : {round(test_score,2)*100}%")
# Out:
# R-squared for training data using random forest: 88.0%
# R-squared for testing data using random forest : 90.0%

# %% [markdown]
# Create a scatter plot with Regression line

# %%
sns.regplot(x = y_train, y = predicted_train_data,
            lowess=True, # add a locally weighted scatterplot smothing line
            line_kws={"color":"red"}, ## the color of the regression line 
            scatter_kws={"alpha":0.25})  ## th transparency of thr scatter points 


plt.title("Y Train Actual VS Y Tain Predicted.".title())
plt.xlabel("Y Train Actual")
plt.ylabel("Y Train Predicted")
plt.show()

# %%
sns.regplot(x = y_test, y = predicted_test_data,
            lowess=True, # add a locally weighted scatterplot smothing line
            line_kws={"color":"red"}, ## the color of the regression line 
            scatter_kws={"alpha":0.25})  ## th transparency of thr scatter points 


plt.title("Y Test Actual VS Y Tain Predicted.".title())
plt.xlabel("Y Test Actual")
plt.ylabel("Y Test Predicted")
plt.show()

# %%
x
# Out:
#            age  sex       bmi  children  smoker  region
# 0    -1.440418    0 -0.453484 -0.909234       1       3
# 1    -1.511647    1  0.513986 -0.079442       0       2
# 2    -0.799350    1  0.382803  1.580143       0       2
# 3    -0.443201    1 -1.306169 -0.909234       0       1
# 4    -0.514431    1 -0.289506 -0.909234       0       1
# ...        ...  ...       ...       ...     ...     ...
# 1333  0.767704    1  0.054847  1.580143       0       1
# 1334 -1.511647    0  0.202427 -0.909234       0       0
# 1335 -1.511647    0  1.022317 -0.909234       0       2
# 1336 -1.297958    0 -0.797838 -0.909234       0       3
# 1337  1.551231    0 -0.256711 -0.909234       1       1
#
# [1337 rows x 6 columns]

# %% [markdown]
# Costomized prediction

# %%
age = 23
sex = 1
bmi = 34
children = 3
smoker = 1
region = 2

# %%
age
# Out:
# 23
